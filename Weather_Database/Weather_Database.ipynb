# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 728

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":current_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
 
    # Add 1 to the record count.
    record_count += 1

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | estrela
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | roald
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | alta floresta
# Processing Record 6 of Set 1 | chulman
# Processing Record 7 of Set 1 | port blair
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | meulaboh
# Processing Record 10 of Set 1 | bambous virieux
# Processing Record 11 of Set 1 | pozo colorado
# Processing Record 12 of Set 1 | luderitz
# Processing Record 13 of Set 1 | ifanadiana
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | oistins
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | khelyulya
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | severo-kurilsk
# Processing Record 27 of Set 1 | camacha
# Processing Record 28 of Set 1 | lata
# Processing Record 29 of Set 1 | vardo
# Processing Record 30 of Set 1 | thio
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | ampanihy
# Processing Record 33 of Set 1 | hofn
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | kolokani
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 1 | bol
# Processing Record 39 of Set 1 | piacabucu
# Processing Record 40 of Set 1 | mount gambier
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | odweyne
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | lagoa
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | tabuk
# Processing Record 49 of Set 1 | rawson
# Processing Record 50 of Set 1 | turukhansk
# Processing Record 1 of Set 2 | college
# Processing Record 2 of Set 2 | yinchuan
# Processing Record 3 of Set 2 | karaton
# Processing Record 4 of Set 2 | port hedland
# Processing Record 5 of Set 2 | airai
# Processing Record 6 of Set 2 | havre-saint-pierre
# Processing Record 7 of Set 2 | frontera
# Processing Record 8 of Set 2 | newberry
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | talara
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | agirish
# Processing Record 14 of Set 2 | oranjemund
# Processing Record 15 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | kitimat
# Processing Record 18 of Set 2 | mbekenyera
# Processing Record 19 of Set 2 | isangel
# Processing Record 20 of Set 2 | mahebourg
# Processing Record 21 of Set 2 | imeni poliny osipenko
# Processing Record 22 of Set 2 | harper
# Processing Record 23 of Set 2 | constitucion
# Processing Record 24 of Set 2 | flinders
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | conceicao do araguaia
# Processing Record 27 of Set 2 | great bend
# Processing Record 28 of Set 2 | lloydminster
# Processing Record 29 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 30 of Set 2 | shubarshi
# Processing Record 31 of Set 2 | mehamn
# Processing Record 32 of Set 2 | te anau
# Processing Record 33 of Set 2 | cap malheureux
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | nanortalik
# Processing Record 36 of Set 2 | parrita
# Processing Record 37 of Set 2 | bonavista
# Processing Record 38 of Set 2 | zhangye
# Processing Record 39 of Set 2 | natchitoches
# Processing Record 40 of Set 2 | tarata
# Processing Record 41 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | roma
# Processing Record 44 of Set 2 | salinopolis
# Processing Record 45 of Set 2 | mirnyy
# Processing Record 46 of Set 2 | agadir
# Processing Record 47 of Set 2 | pecos
# Processing Record 48 of Set 2 | port lincoln
# Processing Record 49 of Set 2 | khoy
# Processing Record 50 of Set 2 | chuy
# Processing Record 1 of Set 3 | tabou
# Processing Record 2 of Set 3 | van
# Processing Record 3 of Set 3 | yumen
# Processing Record 4 of Set 3 | albany
# Processing Record 5 of Set 3 | bluff
# Processing Record 6 of Set 3 | igarka
# Processing Record 7 of Set 3 | tanacu
# Processing Record 8 of Set 3 | taoudenni
# Processing Record 9 of Set 3 | klaksvik
# Processing Record 10 of Set 3 | krasnoselkup
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | manitouwadge
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | plainview
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | sao filipe
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | alofi
# Processing Record 21 of Set 3 | bathsheba
# Processing Record 22 of Set 3 | pevek
# Processing Record 23 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 3 | moses lake
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | belmonte
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | nome
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | suzu
# City not found. Skipping...
# Processing Record 31 of Set 3 | nizhniy kuranakh
# Processing Record 32 of Set 3 | ormilia
# Processing Record 33 of Set 3 | barrow
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | birjand
# Processing Record 36 of Set 3 | kerema
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | namibe
# Processing Record 39 of Set 3 | tuatapere
# Processing Record 40 of Set 3 | deputatskiy
# Processing Record 41 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 3 | kapit
# Processing Record 43 of Set 3 | kaeo
# Processing Record 44 of Set 3 | kavieng
# Processing Record 45 of Set 3 | la ronge
# Processing Record 46 of Set 3 | saint george
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | oxford
# Processing Record 49 of Set 3 | hobart
# Processing Record 50 of Set 3 | hambantota
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | malakal
# Processing Record 3 of Set 4 | port moresby
# Processing Record 4 of Set 4 | litoral del san juan
# City not found. Skipping...
# Processing Record 5 of Set 4 | pueblo
# Processing Record 6 of Set 4 | najran
# Processing Record 7 of Set 4 | lamu
# Processing Record 8 of Set 4 | san cristobal
# Processing Record 9 of Set 4 | kannauj
# Processing Record 10 of Set 4 | mecca
# Processing Record 11 of Set 4 | kapaa
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | phan thiet
# Processing Record 14 of Set 4 | richards bay
# Processing Record 15 of Set 4 | chenzhou
# Processing Record 16 of Set 4 | sinnamary
# Processing Record 17 of Set 4 | torbay
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | tilichiki
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | boffa
# Processing Record 22 of Set 4 | pathein
# Processing Record 23 of Set 4 | cayenne
# Processing Record 24 of Set 4 | new norfolk
# Processing Record 25 of Set 4 | vila franca do campo
# Processing Record 26 of Set 4 | castro
# Processing Record 27 of Set 4 | rio grande
# Processing Record 28 of Set 4 | dezhou
# Processing Record 29 of Set 4 | caravelas
# Processing Record 30 of Set 4 | yarmouth
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | hobe sound
# Processing Record 33 of Set 4 | chimore
# Processing Record 34 of Set 4 | aripuana
# Processing Record 35 of Set 4 | portokhelion
# City not found. Skipping...
# Processing Record 36 of Set 4 | sur
# Processing Record 37 of Set 4 | muros
# Processing Record 38 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 4 | tiksi
# Processing Record 40 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 4 | jumla
# Processing Record 42 of Set 4 | kenora
# Processing Record 43 of Set 4 | bembereke
# Processing Record 44 of Set 4 | arraial do cabo
# Processing Record 45 of Set 4 | pangnirtung
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | sao joao da barra
# Processing Record 48 of Set 4 | mocuba
# Processing Record 49 of Set 4 | kirkwall
# Processing Record 50 of Set 4 | leningradskiy
# Processing Record 1 of Set 5 | anjiang
# Processing Record 2 of Set 5 | diffa
# Processing Record 3 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 5 | berlevag
# Processing Record 5 of Set 5 | bandarbeyla
# Processing Record 6 of Set 5 | talnakh
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | payo
# Processing Record 9 of Set 5 | le vauclin
# Processing Record 10 of Set 5 | zalantun
# Processing Record 11 of Set 5 | svecha
# Processing Record 12 of Set 5 | pokhara
# Processing Record 13 of Set 5 | chama
# Processing Record 14 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 5 | merauke
# Processing Record 16 of Set 5 | chokurdakh
# Processing Record 17 of Set 5 | warrnambool
# Processing Record 18 of Set 5 | pisco
# Processing Record 19 of Set 5 | bon air
# Processing Record 20 of Set 5 | mega
# Processing Record 21 of Set 5 | pangody
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | ust-kuyga
# Processing Record 24 of Set 5 | oliveira dos brejinhos
# Processing Record 25 of Set 5 | husavik
# Processing Record 26 of Set 5 | sterling
# Processing Record 27 of Set 5 | itaporanga
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | boulsa
# Processing Record 30 of Set 5 | nicoya
# Processing Record 31 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 5 | yerofey pavlovich
# Processing Record 33 of Set 5 | aykhal
# Processing Record 34 of Set 5 | ust-maya
# Processing Record 35 of Set 5 | carutapera
# Processing Record 36 of Set 5 | palanga
# Processing Record 37 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 5 | tuban
# Processing Record 39 of Set 5 | ranong
# Processing Record 40 of Set 5 | srandakan
# Processing Record 41 of Set 5 | lavrentiya
# Processing Record 42 of Set 5 | vaisala
# City not found. Skipping...
# Processing Record 43 of Set 5 | murzzuschlag
# Processing Record 44 of Set 5 | sorland
# Processing Record 45 of Set 5 | vila velha
# Processing Record 46 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 47 of Set 5 | faanui
# Processing Record 48 of Set 5 | elizabeth city
# Processing Record 49 of Set 5 | rudnogorsk
# Processing Record 50 of Set 5 | ambulu
# Processing Record 1 of Set 6 | tommot
# Processing Record 2 of Set 6 | kruisfontein
# Processing Record 3 of Set 6 | portland
# Processing Record 4 of Set 6 | inyonga
# Processing Record 5 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 6 | ribeira grande
# Processing Record 7 of Set 6 | lesosibirsk
# Processing Record 8 of Set 6 | svobodnyy
# Processing Record 9 of Set 6 | bowen
# Processing Record 10 of Set 6 | mareeba
# Processing Record 11 of Set 6 | upernavik
# Processing Record 12 of Set 6 | guhagar
# Processing Record 13 of Set 6 | tautira
# Processing Record 14 of Set 6 | souillac
# Processing Record 15 of Set 6 | vallenar
# Processing Record 16 of Set 6 | ekhabi
# Processing Record 17 of Set 6 | ormara
# Processing Record 18 of Set 6 | tasiilaq
# Processing Record 19 of Set 6 | ugoofaaru
# Processing Record 20 of Set 6 | doka
# Processing Record 21 of Set 6 | saskylakh
# Processing Record 22 of Set 6 | havelock
# Processing Record 23 of Set 6 | belyy yar
# Processing Record 24 of Set 6 | tonj
# Processing Record 25 of Set 6 | makat
# Processing Record 26 of Set 6 | tongliao
# Processing Record 27 of Set 6 | vaitape
# Processing Record 28 of Set 6 | mount isa
# Processing Record 29 of Set 6 | port lavaca
# Processing Record 30 of Set 6 | mugur-aksy
# Processing Record 31 of Set 6 | vostok
# Processing Record 32 of Set 6 | finschhafen
# Processing Record 33 of Set 6 | kavaratti
# Processing Record 34 of Set 6 | prince rupert
# Processing Record 35 of Set 6 | sargans
# Processing Record 36 of Set 6 | gat
# Processing Record 37 of Set 6 | atar
# Processing Record 38 of Set 6 | cabedelo
# Processing Record 39 of Set 6 | esperance
# Processing Record 40 of Set 6 | nazarovo
# Processing Record 41 of Set 6 | otradnoye
# Processing Record 42 of Set 6 | hami
# Processing Record 43 of Set 6 | thompson
# Processing Record 44 of Set 6 | kahului
# Processing Record 45 of Set 6 | honningsvag
# Processing Record 46 of Set 6 | moiyabana
# City not found. Skipping...
# Processing Record 47 of Set 6 | kambove
# Processing Record 48 of Set 6 | ust-ishim
# Processing Record 49 of Set 6 | stornoway
# Processing Record 50 of Set 6 | gravdal
# Processing Record 1 of Set 7 | kraslava
# Processing Record 2 of Set 7 | aguimes
# Processing Record 3 of Set 7 | bambanglipuro
# Processing Record 4 of Set 7 | san-pedro
# Processing Record 5 of Set 7 | haines junction
# Processing Record 6 of Set 7 | sabang
# Processing Record 7 of Set 7 | henties bay
# Processing Record 8 of Set 7 | llangefni
# Processing Record 9 of Set 7 | rio gallegos
# Processing Record 10 of Set 7 | guerrero negro
# Processing Record 11 of Set 7 | mnogovershinnyy
# Processing Record 12 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 7 | reconquista
# Processing Record 14 of Set 7 | leh
# Processing Record 15 of Set 7 | jardim
# Processing Record 16 of Set 7 | maksatikha
# Processing Record 17 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 18 of Set 7 | vao
# Processing Record 19 of Set 7 | arlit
# Processing Record 20 of Set 7 | isiro
# Processing Record 21 of Set 7 | kortkeros
# Processing Record 22 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 7 | umm kaddadah
# Processing Record 24 of Set 7 | plettenberg bay
# Processing Record 25 of Set 7 | lorengau
# Processing Record 26 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 27 of Set 7 | fortuna
# Processing Record 28 of Set 7 | samarai
# Processing Record 29 of Set 7 | evensk
# Processing Record 30 of Set 7 | sambava
# Processing Record 31 of Set 7 | ust-tsilma
# Processing Record 32 of Set 7 | dingle
# Processing Record 33 of Set 7 | karachi
# Processing Record 34 of Set 7 | san patricio
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | waddan
# Processing Record 37 of Set 7 | kieta
# Processing Record 38 of Set 7 | kudamatsu
# Processing Record 39 of Set 7 | vidisha
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | tsaratanana
# Processing Record 42 of Set 7 | fort nelson
# Processing Record 43 of Set 7 | asyut
# Processing Record 44 of Set 7 | kangaba
# Processing Record 45 of Set 7 | komsomolskiy
# Processing Record 46 of Set 7 | havoysund
# Processing Record 47 of Set 7 | ossora
# Processing Record 48 of Set 7 | porto novo
# Processing Record 49 of Set 7 | hokitika
# Processing Record 50 of Set 7 | noyabrsk
# Processing Record 1 of Set 8 | charyshskoye
# Processing Record 2 of Set 8 | bengkulu
# Processing Record 3 of Set 8 | trelew
# Processing Record 4 of Set 8 | clyde river
# Processing Record 5 of Set 8 | gasa
# Processing Record 6 of Set 8 | machali
# Processing Record 7 of Set 8 | nchelenge
# Processing Record 8 of Set 8 | ilulissat
# Processing Record 9 of Set 8 | navoi
# Processing Record 10 of Set 8 | grindavik
# Processing Record 11 of Set 8 | kinkala
# Processing Record 12 of Set 8 | mende
# Processing Record 13 of Set 8 | elko
# Processing Record 14 of Set 8 | okhotsk
# Processing Record 15 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 8 | erzin
# Processing Record 17 of Set 8 | aksu
# Processing Record 18 of Set 8 | oga
# Processing Record 19 of Set 8 | ust-nera
# Processing Record 20 of Set 8 | nobres
# Processing Record 21 of Set 8 | la palma
# Processing Record 22 of Set 8 | progreso
# Processing Record 23 of Set 8 | birao
# Processing Record 24 of Set 8 | tiznit
# Processing Record 25 of Set 8 | sennan
# Processing Record 26 of Set 8 | marawi
# Processing Record 27 of Set 8 | burgeo
# Processing Record 28 of Set 8 | aquiraz
# Processing Record 29 of Set 8 | oshnaviyeh
# Processing Record 30 of Set 8 | kutum
# Processing Record 31 of Set 8 | san andres
# Processing Record 32 of Set 8 | yaan
# Processing Record 33 of Set 8 | gisborne
# Processing Record 34 of Set 8 | valday
# Processing Record 35 of Set 8 | hervey bay
# Processing Record 36 of Set 8 | qarqin
# Processing Record 37 of Set 8 | santa isabel
# Processing Record 38 of Set 8 | sociedad
# Processing Record 39 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 8 | vila
# Processing Record 41 of Set 8 | brae
# Processing Record 42 of Set 8 | azrow
# City not found. Skipping...
# Processing Record 43 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 44 of Set 8 | ponnani
# Processing Record 45 of Set 8 | tucupita
# Processing Record 46 of Set 8 | namatanai
# Processing Record 47 of Set 8 | sergeyevka
# Processing Record 48 of Set 8 | olafsvik
# Processing Record 49 of Set 8 | touros
# Processing Record 50 of Set 8 | antalaha
# Processing Record 1 of Set 9 | imbituba
# Processing Record 2 of Set 9 | santa maria
# Processing Record 3 of Set 9 | stevens point
# Processing Record 4 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 9 | ishigaki
# Processing Record 6 of Set 9 | port shepstone
# Processing Record 7 of Set 9 | akyab
# Processing Record 8 of Set 9 | chipinge
# Processing Record 9 of Set 9 | rovaniemi
# Processing Record 10 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 11 of Set 9 | amazar
# Processing Record 12 of Set 9 | yubari
# Processing Record 13 of Set 9 | chifeng
# Processing Record 14 of Set 9 | tura
# Processing Record 15 of Set 9 | jinchang
# Processing Record 16 of Set 9 | shieli
# Processing Record 17 of Set 9 | torbat-e jam
# Processing Record 18 of Set 9 | mandalgovi
# Processing Record 19 of Set 9 | honghu
# Processing Record 20 of Set 9 | riviere-au-renard
# Processing Record 21 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 9 | labuhan
# Processing Record 23 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 9 | yuancheng
# Processing Record 25 of Set 9 | paamiut
# Processing Record 26 of Set 9 | maniitsoq
# Processing Record 27 of Set 9 | abha
# Processing Record 28 of Set 9 | hobyo
# Processing Record 29 of Set 9 | sikasso
# Processing Record 30 of Set 9 | tanout
# Processing Record 31 of Set 9 | bauchi
# Processing Record 32 of Set 9 | korla
# Processing Record 33 of Set 9 | dwarka
# Processing Record 34 of Set 9 | soyo
# Processing Record 35 of Set 9 | hella
# Processing Record 36 of Set 9 | iqaluit
# Processing Record 37 of Set 9 | apt
# Processing Record 38 of Set 9 | xuddur
# Processing Record 39 of Set 9 | kabo
# Processing Record 40 of Set 9 | lethem
# Processing Record 41 of Set 9 | solano
# Processing Record 42 of Set 9 | amahai
# Processing Record 43 of Set 9 | nelson bay
# Processing Record 44 of Set 9 | chalus
# Processing Record 45 of Set 9 | vestmanna
# Processing Record 46 of Set 9 | acapulco
# Processing Record 47 of Set 9 | midleton
# Processing Record 48 of Set 9 | puerto del rosario
# Processing Record 49 of Set 9 | berbera
# Processing Record 50 of Set 9 | iquique
# Processing Record 1 of Set 10 | magistralnyy
# Processing Record 2 of Set 10 | grand prairie
# Processing Record 3 of Set 10 | terracina
# Processing Record 4 of Set 10 | ponta do sol
# Processing Record 5 of Set 10 | manggar
# Processing Record 6 of Set 10 | villazon
# Processing Record 7 of Set 10 | yerbogachen
# Processing Record 8 of Set 10 | flagstaff
# Processing Record 9 of Set 10 | balikpapan
# Processing Record 10 of Set 10 | tabatinga
# Processing Record 11 of Set 10 | karratha
# Processing Record 12 of Set 10 | kijang
# Processing Record 13 of Set 10 | oudtshoorn
# Processing Record 14 of Set 10 | bendigo
# Processing Record 15 of Set 10 | dunedin
# Processing Record 16 of Set 10 | chicama
# Processing Record 17 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 10 | cururupu
# Processing Record 19 of Set 10 | lodwar
# Processing Record 20 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 10 | ayan
# Processing Record 22 of Set 10 | gushikawa
# Processing Record 23 of Set 10 | langham
# Processing Record 24 of Set 10 | kaitangata
# Processing Record 25 of Set 10 | kamina
# Processing Record 26 of Set 10 | gouyave
# Processing Record 27 of Set 10 | kirundo
# Processing Record 28 of Set 10 | angoche
# Processing Record 29 of Set 10 | faya
# Processing Record 30 of Set 10 | eloi mendes
# Processing Record 31 of Set 10 | lambarene
# Processing Record 32 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 10 | tromso
# Processing Record 34 of Set 10 | nouadhibou
# Processing Record 35 of Set 10 | vestmannaeyjar
# Processing Record 36 of Set 10 | port hardy
# Processing Record 37 of Set 10 | griffith
# Processing Record 38 of Set 10 | salalah
# Processing Record 39 of Set 10 | oktyabrskoye
# Processing Record 40 of Set 10 | riachao do jacuipe
# Processing Record 41 of Set 10 | jinja
# Processing Record 42 of Set 10 | umm lajj
# Processing Record 43 of Set 10 | xihua
# Processing Record 44 of Set 10 | gao
# Processing Record 45 of Set 10 | fort morgan
# Processing Record 46 of Set 10 | zyryanka
# Processing Record 47 of Set 10 | surt
# Processing Record 48 of Set 10 | kaseda
# Processing Record 49 of Set 10 | sao miguel do araguaia
# Processing Record 50 of Set 10 | novoilinsk
# Processing Record 1 of Set 11 | formosa
# Processing Record 2 of Set 11 | le port
# Processing Record 3 of Set 11 | parras
# City not found. Skipping...
# Processing Record 4 of Set 11 | margate
# Processing Record 5 of Set 11 | axim
# Processing Record 6 of Set 11 | solnechnyy
# Processing Record 7 of Set 11 | fuerte olimpo
# Processing Record 8 of Set 11 | puerto rico
# Processing Record 9 of Set 11 | kirakira
# Processing Record 10 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 11 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 11 | lasa
# Processing Record 13 of Set 11 | cabo san lucas
# Processing Record 14 of Set 11 | flin flon
# Processing Record 15 of Set 11 | mukhen
# Processing Record 16 of Set 11 | kauhajoki
# Processing Record 17 of Set 11 | raahe
# Processing Record 18 of Set 11 | lisala
# Processing Record 19 of Set 11 | wattegama
# Processing Record 20 of Set 11 | gamba
# Processing Record 21 of Set 11 | homer
# Processing Record 22 of Set 11 | lerwick
# Processing Record 23 of Set 11 | madras
# Processing Record 24 of Set 11 | katangli
# Processing Record 25 of Set 11 | olavarria
# Processing Record 26 of Set 11 | duki
# Processing Record 27 of Set 11 | buraydah
# Processing Record 28 of Set 11 | sao joao dos patos
# Processing Record 29 of Set 11 | boende
# Processing Record 30 of Set 11 | north myrtle beach
# Processing Record 31 of Set 11 | tahe
# Processing Record 32 of Set 11 | anadyr
# Processing Record 33 of Set 11 | hubli
# Processing Record 34 of Set 11 | valle hermoso
# Processing Record 35 of Set 11 | peruc
# Processing Record 36 of Set 11 | yongan
# Processing Record 37 of Set 11 | yar-sale
# Processing Record 38 of Set 11 | ihosy
# Processing Record 39 of Set 11 | lucero
# Processing Record 40 of Set 11 | chaiya
# Processing Record 41 of Set 11 | kopavogur
# Processing Record 42 of Set 11 | savalou
# Processing Record 43 of Set 11 | timbiqui
# Processing Record 44 of Set 11 | sinop
# Processing Record 45 of Set 11 | maceio
# Processing Record 46 of Set 11 | itarema
# Processing Record 47 of Set 11 | kismayo
# Processing Record 48 of Set 11 | saint-francois
# Processing Record 49 of Set 11 | macerata
# Processing Record 50 of Set 11 | sol-iletsk
# Processing Record 1 of Set 12 | batagay-alyta
# Processing Record 2 of Set 12 | denton
# Processing Record 3 of Set 12 | ankazoabo
# Processing Record 4 of Set 12 | saint anthony
# Processing Record 5 of Set 12 | broken hill
# Processing Record 6 of Set 12 | tezu
# Processing Record 7 of Set 12 | houma
# Processing Record 8 of Set 12 | arman
# Processing Record 9 of Set 12 | broome
# Processing Record 10 of Set 12 | matata
# Processing Record 11 of Set 12 | canton
# Processing Record 12 of Set 12 | buchanan
# Processing Record 13 of Set 12 | menongue
# Processing Record 14 of Set 12 | pemba
# Processing Record 15 of Set 12 | rusape
# Processing Record 16 of Set 12 | mabai
# Processing Record 17 of Set 12 | rapid valley
# Processing Record 18 of Set 12 | miandrivazo
# Processing Record 19 of Set 12 | manadhoo
# Processing Record 20 of Set 12 | bud
# Processing Record 21 of Set 12 | cadereyta
# Processing Record 22 of Set 12 | conde
# Processing Record 23 of Set 12 | baruun-urt
# Processing Record 24 of Set 12 | mahibadhoo
# Processing Record 25 of Set 12 | salina cruz
# Processing Record 26 of Set 12 | prince george
# Processing Record 27 of Set 12 | santa fe
# Processing Record 28 of Set 12 | puerto ayacucho
# Processing Record 29 of Set 12 | morondava
# Processing Record 30 of Set 12 | kalabo
# Processing Record 31 of Set 12 | geraldton
# Processing Record 32 of Set 12 | termoli
# Processing Record 33 of Set 12 | kulachi
# Processing Record 34 of Set 12 | ucluelet
# Processing Record 35 of Set 12 | awjilah
# Processing Record 36 of Set 12 | waingapu
# Processing Record 37 of Set 12 | katsuura
# Processing Record 38 of Set 12 | guiglo
# Processing Record 39 of Set 12 | coquimbo
# Processing Record 40 of Set 12 | ajaccio
# Processing Record 41 of Set 12 | yulara
# Processing Record 42 of Set 12 | sitio novo do tocantins
# Processing Record 43 of Set 12 | domoni
# Processing Record 44 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 45 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 46 of Set 12 | matamoros
# Processing Record 47 of Set 12 | stephenville crossing
# Processing Record 48 of Set 12 | nuuk
# Processing Record 49 of Set 12 | padang
# Processing Record 50 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 1 of Set 13 | deer lake
# Processing Record 2 of Set 13 | taunggyi
# Processing Record 3 of Set 13 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 4 of Set 13 | antsohihy
# Processing Record 5 of Set 13 | tala
# Processing Record 6 of Set 13 | okato
# Processing Record 7 of Set 13 | sanquhar
# Processing Record 8 of Set 13 | kabalo
# Processing Record 9 of Set 13 | zabol
# Processing Record 10 of Set 13 | russell
# Processing Record 11 of Set 13 | cascais
# Processing Record 12 of Set 13 | katherine
# Processing Record 13 of Set 13 | purpe
# Processing Record 14 of Set 13 | tan an
# Processing Record 15 of Set 13 | hamilton
# Processing Record 16 of Set 13 | biak
# Processing Record 17 of Set 13 | porvoo
# Processing Record 18 of Set 13 | ewa beach
# Processing Record 19 of Set 13 | hanzhong
# Processing Record 20 of Set 13 | play cu
# City not found. Skipping...
# Processing Record 21 of Set 13 | los llanos de aridane
# Processing Record 22 of Set 13 | monrovia
# Processing Record 23 of Set 13 | adana
# Processing Record 24 of Set 13 | saint-joseph
# Processing Record 25 of Set 13 | greeneville
# Processing Record 26 of Set 13 | opuwo
# Processing Record 27 of Set 13 | saiha
# Processing Record 28 of Set 13 | ahipara
# Processing Record 29 of Set 13 | naze
# Processing Record 30 of Set 13 | kemijarvi
# Processing Record 31 of Set 13 | nouakchott
# Processing Record 32 of Set 13 | barranca
# Processing Record 33 of Set 13 | barra do garcas
# Processing Record 34 of Set 13 | ramon castilla
# Processing Record 35 of Set 13 | chlorakas
# Processing Record 36 of Set 13 | kirksville
# Processing Record 37 of Set 13 | porto nacional
# Processing Record 38 of Set 13 | chapleau
# Processing Record 39 of Set 13 | nampa
# Processing Record 40 of Set 13 | bitung
# Processing Record 41 of Set 13 | toropets
# Processing Record 42 of Set 13 | jobat
# Processing Record 43 of Set 13 | pinheiro machado
# Processing Record 44 of Set 13 | novonukutskiy
# Processing Record 45 of Set 13 | san vicente
# Processing Record 46 of Set 13 | sibolga
# Processing Record 47 of Set 13 | tessalit
# Processing Record 48 of Set 13 | helong
# Processing Record 49 of Set 13 | paungde
# Processing Record 50 of Set 13 | victor harbor
# Processing Record 1 of Set 14 | ixtapa
# Processing Record 2 of Set 14 | mushie
# Processing Record 3 of Set 14 | redcliffe
# Processing Record 4 of Set 14 | nago
# Processing Record 5 of Set 14 | yenagoa
# Processing Record 6 of Set 14 | oranjestad
# Processing Record 7 of Set 14 | vyartsilya
# Processing Record 8 of Set 14 | mitu
# Processing Record 9 of Set 14 | hit
# Processing Record 10 of Set 14 | hastings
# Processing Record 11 of Set 14 | azanka
# Processing Record 12 of Set 14 | emerald
# Processing Record 13 of Set 14 | ozu
# Processing Record 14 of Set 14 | qaqortoq
# Processing Record 15 of Set 14 | seoul
# Processing Record 16 of Set 14 | indore
# Processing Record 17 of Set 14 | male
# Processing Record 18 of Set 14 | riyadh
# Processing Record 19 of Set 14 | ramhormoz
# Processing Record 20 of Set 14 | takoradi
# Processing Record 21 of Set 14 | marevo
# Processing Record 22 of Set 14 | santa cruz del sur
# Processing Record 23 of Set 14 | uddevalla
# Processing Record 24 of Set 14 | oriximina
# Processing Record 25 of Set 14 | adrar
# Processing Record 26 of Set 14 | kurdzhinovo
# Processing Record 27 of Set 14 | swift current
# Processing Record 28 of Set 14 | bichura
# Processing Record 29 of Set 14 | maumere
# Processing Record 30 of Set 14 | tacoronte
# Processing Record 31 of Set 14 | zhicheng
# Processing Record 32 of Set 14 | north bend
# Processing Record 33 of Set 14 | sept-iles
# Processing Record 34 of Set 14 | puerto carreno
# Processing Record 35 of Set 14 | carbondale
# Processing Record 36 of Set 14 | aswan
# Processing Record 37 of Set 14 | jiuquan
# Processing Record 38 of Set 14 | teya
# Processing Record 39 of Set 14 | kraste
# City not found. Skipping...
# Processing Record 40 of Set 14 | dunda
# Processing Record 41 of Set 14 | udaipur
# Processing Record 42 of Set 14 | haukipudas
# Processing Record 43 of Set 14 | farafangana
# Processing Record 44 of Set 14 | collie
# Processing Record 45 of Set 14 | neiafu
# Processing Record 46 of Set 14 | ternate
# Processing Record 47 of Set 14 | sola
# Processing Record 48 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 14 | half moon bay
# Processing Record 50 of Set 14 | klyuchi
# Processing Record 1 of Set 15 | abonnema
# Processing Record 2 of Set 15 | gobabis
# Processing Record 3 of Set 15 | leshan
# Processing Record 4 of Set 15 | navrongo
# Processing Record 5 of Set 15 | camacari
# Processing Record 6 of Set 15 | quelimane
# Processing Record 7 of Set 15 | conceicao das alagoas
# Processing Record 8 of Set 15 | benguela
# Processing Record 9 of Set 15 | xiangfan
# Processing Record 10 of Set 15 | prainha
# Processing Record 11 of Set 15 | marzuq
# Processing Record 12 of Set 15 | bosilegrad
# Processing Record 13 of Set 15 | huilong
# Processing Record 14 of Set 15 | rock springs
# Processing Record 15 of Set 15 | rayong
# Processing Record 16 of Set 15 | karanganyar
# Processing Record 17 of Set 15 | chihuahua
# Processing Record 18 of Set 15 | jalu
# Processing Record 19 of Set 15 | mgachi
# Processing Record 20 of Set 15 | tucurui
# Processing Record 21 of Set 15 | rancho palos verdes
# Processing Record 22 of Set 15 | muisne
# Processing Record 23 of Set 15 | metro
# Processing Record 24 of Set 15 | bure
# Processing Record 25 of Set 15 | fukue
# Processing Record 26 of Set 15 | yakeshi
# Processing Record 27 of Set 15 | palmer
# Processing Record 28 of Set 15 | zaraza
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Estrela -28.0611  -50.9383     73.22        45          50
# 1          Mataura -46.1927  168.8643     50.49        97          78
# 2            Roald  62.5833    6.1333     39.33        60          75
# 3           Avarua -21.2078 -159.7750     73.45       100          90
# 4    Alta Floresta  -9.8756  -56.0861     87.62        66          40
# 5          Chulman  56.8479  124.9104    -12.15        98          99
# 6       Port Blair  11.6667   92.7500     79.93        69          49
# 7         Cherskiy  68.7500  161.3000    -40.04       100          82
# 8         Meulaboh   4.1363   96.1285     78.89        80          71
# 9  Bambous Virieux -20.3428   57.7575     79.05        73          40
#
#    Wind Speed Country Current Description
# 0        6.96      BR    scattered clouds
# 1        2.55      NZ       broken clouds
# 2       14.97      NO       broken clouds
# 3        2.30      CK          light rain
# 4        5.75      BR    scattered clouds
# 5        3.49      RU     overcast clouds
# 6       13.29      IN    scattered clouds
# 7        2.57      RU       broken clouds
# 8        3.20      ID       broken clouds
# 9        8.05      MU          light rain

# %%
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Estrela      BR -28.0611  -50.9383     73.22        45          50
# 1          Mataura      NZ -46.1927  168.8643     50.49        97          78
# 2            Roald      NO  62.5833    6.1333     39.33        60          75
# 3           Avarua      CK -21.2078 -159.7750     73.45       100          90
# 4    Alta Floresta      BR  -9.8756  -56.0861     87.62        66          40
# 5          Chulman      RU  56.8479  124.9104    -12.15        98          99
# 6       Port Blair      IN  11.6667   92.7500     79.93        69          49
# 7         Cherskiy      RU  68.7500  161.3000    -40.04       100          82
# 8         Meulaboh      ID   4.1363   96.1285     78.89        80          71
# 9  Bambous Virieux      MU -20.3428   57.7575     79.05        73          40
#
#    Wind Speed Current Description
# 0        6.96    scattered clouds
# 1        2.55       broken clouds
# 2       14.97       broken clouds
# 3        2.30          light rain
# 4        5.75    scattered clouds
# 5        3.49     overcast clouds
# 6       13.29    scattered clouds
# 7        2.57       broken clouds
# 8        3.20       broken clouds
# 9        8.05          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
